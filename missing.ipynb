# %% [markdown]
# ### Import your libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load your dataset

# %%
Df= pd.read_csv('HR_Missing_Vslues.csv')
Df
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi, Wilson  K  10026   62506.0          19
# 1    Ait Sidi, Karthikeyan     10084  104437.0          27
# 2           Akinkuolie, Sarah  10196   64955.0          20
# 3                Alagbe,Trina  10088   64991.0          19
# 4                         NaN  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson, Jason  10135   65893.0          20
# 307        Ybarra, Catherine   10301   48513.0          19
# 308                       NaN  10010  220450.0           6
# 309               Zhou, Julia  10043   89292.0           9
# 310                       NaN  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...

# %% [markdown]
# ### Explore your data
#
# * First 5 recods
# * Last 5 records
# * Check data type
# * Show statistical summary
# * Is there any missing values ?
# * Applay two more data analysis from your choose

# %%
Df.head(5)
# Out:
#               Employee_Name  EmpID    Salary  PositionID  \
# 0       Adinolfi, Wilson  K  10026   62506.0          19
# 1  Ait Sidi, Karthikeyan     10084  104437.0          27
# 2         Akinkuolie, Sarah  10196   64955.0          20
# 3              Alagbe,Trina  10088   64991.0          19
# 4                       NaN  10069   50825.0          19
#
#                    Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0   Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                   Sr. DBA  05/05/75  M      Married    White  3/30/2015
# 2  Production Technician II  09/19/88   F     Married    White   7/5/2011
# 3   Production Technician I       NaN   F     Married    White   1/7/2008
# 4   Production Technician I  09/08/89   F    Divorced    White  7/11/2011
#
#   DateofTermination         Department     ManagerName  ManagerID  \
# 0               NaN  Production         Michael Albert       22.0
# ...

# %%
Df.tail(5)
# Out:
#           Employee_Name  EmpID    Salary  PositionID  \
# 306      Woodson, Jason  10135   65893.0          20
# 307  Ybarra, Catherine   10301   48513.0          19
# 308                 NaN  10010  220450.0           6
# 309         Zhou, Julia  10043   89292.0           9
# 310                 NaN  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 306  Production Technician II  05/11/85  M       Single    White   7/7/2014
# 307   Production Technician I       NaN   F      Single    Asian   9/2/2008
# 308                       CIO       NaN   F      Single    White  4/10/2010
# 309              Data Analyst  02/24/79   F      Single    White  3/30/2015
# 310   Production Technician I  08/17/78   F     Widowed    Asian  9/29/2014
#
#     DateofTermination         Department     ManagerName  ManagerID  \
# 306               NaN  Production         Kissy Sullivan       20.0
# ...

# %%
Df.dtypes
# Out:
# Employee_Name         object
# EmpID                  int64
# Salary               float64
# PositionID             int64
# Position              object
# DOB                   object
# Sex                   object
# MaritalDesc           object
# RaceDesc              object
# DateofHire            object
# DateofTermination     object
# Department            object
# ManagerName           object
# ManagerID            float64
# RecruitmentSource     object
# Absences             float64
# dtype: object

# %%
Df.describe()
# Out:
#               EmpID         Salary  PositionID   ManagerID    Absences
# count    311.000000     249.000000  311.000000  303.000000  280.000000
# mean   10156.000000   67972.662651   16.845659   14.570957   10.128571
# std       89.922189   22995.908395    6.223419    8.078306    5.946407
# min    10001.000000   45046.000000    1.000000    1.000000    1.000000
# 25%    10078.500000   55315.000000   18.000000   10.000000    4.750000
# 50%    10156.000000   62957.000000   19.000000   15.000000   10.000000
# 75%    10233.500000   71707.000000   20.000000   19.000000   15.250000
# max    10311.000000  220450.000000   30.000000   39.000000   20.000000

# %%
Df.isnull().sum()
# Out:
# Employee_Name         93
# EmpID                  0
# Salary                62
# PositionID             0
# Position               0
# DOB                   31
# Sex                   62
# MaritalDesc            0
# RaceDesc               0
# DateofHire             0
# DateofTermination    207
# Department             0
# ManagerName            0
# ManagerID              8
# RecruitmentSource      0
# Absences              31
# dtype: int64

# %%
Df.isnull()
# Out:
#      Employee_Name  EmpID  Salary  PositionID  Position    DOB    Sex  \
# 0            False  False   False       False     False  False  False
# 1            False  False   False       False     False  False  False
# 2            False  False   False       False     False  False  False
# 3            False  False   False       False     False   True  False
# 4             True  False   False       False     False  False  False
# ..             ...    ...     ...         ...       ...    ...    ...
# 306          False  False   False       False     False  False  False
# 307          False  False   False       False     False   True  False
# 308           True  False   False       False     False   True  False
# 309          False  False   False       False     False  False  False
# 310           True  False   False       False     False  False  False
#
#      MaritalDesc  RaceDesc  DateofHire  DateofTermination  Department  \
# ...

# %% [markdown]
# ### Do the following steps for each column with missing values.
#
# * Identity the column
# * How much precentage the missing value represents
# * What is the best way to handle these missing values and why
# * Apply yourr method to the column

# %%
missing_value=Df.isnull().sum()
total_cells = np.product(Df.shape)
total_missing = missing_value.sum()
(total_missing/total_cells) * 100
# Out:
# 9.92765273311897

# %%
Df["Sex"].fillna("No Gender", inplace = True) # ممكن امثلها في البيانات غير محدد

# %%
Df['Salary'].plot(kind="hist");

# %%
mean= round(Df.Salary.mean())# طلعت المين 
mean
# Out:
# 67973

# %%
    Q1= np.quantile(Df['Salary'],0.25)
    Q3= np.quantile(Df['Salary'],0.75)
    IOR=Q3-Q1
    threshold=1.5*IOR
    lower=Q1-threshold
    upper=Q3+threshold
    lower_bound=Df[Df['Salary']<=lower].index
    upper_bound=Df[Df['Salary']>=upper].index # حددت الرواتب الاعلى والاقل بسبب لاتعطعى لي اغلب الموظفين

# %%
Df.drop( lower_bound| upper_bound, inplace = True)#حذفتهم
# Out:
# C:\Users\96650\AppData\Local\Temp\ipykernel_18308\4226758049.py:1: FutureWarning:
#
# Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.

# %%
mean= round(Df.Salary.mean())
mean
# Out:
# 61931

# %%
Df['Salary']= Df['Salary'].fillna(mean) # عوضت في المين لرواتب

# %%
Df['Salary'].plot(kind="hist"); #

# %%
Df.isnull().sum()
# Out:
# Employee_Name         78
# EmpID                  0
# Salary                 0
# PositionID             0
# Position               0
# DOB                   27
# Sex                    0
# MaritalDesc            0
# RaceDesc               0
# DateofHire             0
# DateofTermination    176
# Department             0
# ManagerName            0
# ManagerID              8
# RecruitmentSource      0
# Absences              24
# dtype: int64
